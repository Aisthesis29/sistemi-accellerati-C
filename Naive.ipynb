# %% [markdown]
# <a href="https://colab.research.google.com/github/Aisthesis29/sistemi-accellerati-C/blob/main/Naive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/Aisthesis29/sistemi-accellerati-C.git
# %cd sistemi-accelerati-C
# Out:
# /content
# Cloning into 'sistemi-accellerati-C'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 150 (delta 84), reused 96 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (150/150), 10.16 MiB | 19.16 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# [Errno 2] No such file or directory: 'sistemi-accelerati-C'
# /content

# %%
# %cd sistemi-accellerati-C/
# Out:
# /content/sistemi-accellerati-C

# %%
# !pwd
# Out:
# /content/sistemi-accellerati-C

# %%
# !git add *
# !git commit -m "colab brutto"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.email "mirkojudo02@gmail.com"
# !git config --global user.name "MirkoTonelli"

# %%
# !git pull
# Out:
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 60 (delta 43), reused 38 (delta 21), pack-reused 0 (from 0)
# Unpacking objects: 100% (60/60), 7.52 KiB | 405.00 KiB/s, done.
# From https://github.com/Aisthesis29/sistemi-accellerati-C
#    964cc66..4de62b2  main       -> origin/main
#  * [new branch]      a          -> origin/a
#  * [new branch]      b          -> origin/b
# Updating 964cc66..4de62b2
# Fast-forward
#  .vscode/tasks.json   |  28 +++++++++
#  convolution/naive.c  |  45 +++++++++-----
#  convolution/naive.cu | 165 +++++++++++++++++++++++++++++++++++++++++++++++++++
#  3 files changed, 224 insertions(+), 14 deletions(-)
#  create mode 100644 .vscode/tasks.json
#  create mode 100644 convolution/naive.cu

# %%
# %cd convolution
# Out:
# /content/sistemi-accellerati-C/convolution

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 354 bytes | 354.00 KiB/s, done.
# From https://github.com/Aisthesis29/sistemi-accellerati-C
#    a1f1b46..6ad2720  main       -> origin/main
# Updating a1f1b46..6ad2720
# Fast-forward
#  convolution/naive.cu | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !nvcc naive.cu -o gpu
# Out:
# stb_image.h(4276): warning #550-D: variable "old_limit" was set but never used
#      unsigned int cur, limit, old_limit;
#                               ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# stb_image.h(5185): warning #550-D: variable "idata_limit_old" was set but never used
#                  stbi__uint32 idata_limit_old = idata_limit;
#                               ^
#
# stb_image.h(6972): warning #550-D: variable "out_size" was set but never used
#         int out_size = 0;
#             ^
#
# stb_image.h(6973): warning #550-D: variable "delays_size" was set but never used
#         int delays_size = 0;
#             ^

# %%
# !./gpu
# Out:
# Image loaded: 450x300 with 3 channels
# Finito greyscale
# FinitoFinito tutto!!
